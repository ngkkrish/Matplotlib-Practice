# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[10,20,30,40])
plt.ylabel("some value Y")
plt.xlabel("some value X")
plt.show()

# %%
plt.plot([100,200,300,400],[150,250,360,400],'-.')
plt.ylabel("X")
plt.xlabel("Y")
plt.show()

# %%
import numpy as np

# %%
t=np.arange(1,20,3,'int64')
print(t)
# Out:
# [ 1  4  7 10 13 16 19]

# %%
plt.plot(t,t,'go')

# %%
plt.plot(t,t,'g^',t,t**2,'r-.')

# %%
# learn and practice MATPLOTLIB.PYPLOT.HIST()

import numpy as np

#np.random.seed(132)
mu=121
sigma=21
np.random.randint(low=1,high=200,size=30)
# Out:
# array([ 38,  17, 114,  13, 110,  50,  20,  21,  11,  91,  84,  57, 118,
#         29, 141, 180,   2,  85, 118,  19, 131,  12, 127, 194,  13,  48,
#        177, 123,  81, 111])

# %% [markdown]
# np.random.randn(1000)
